# %% [markdown]
# #European RosettaCon 2022 - Docking Session

# %% [markdown]
# ###Theoretical aspects
#
# As more and more protein structures are determined experimentally using X-ray crystallography or nuclear magnetic resonance (NMR) spectroscopy, molecular docking is increasingly used as a tool in **drug discovery**.
#
# **Molecular docking simulations** explore the potential binding poses of small molecules on the **binding site** of a target protein for which an experimentally determined structure is available.
# Docking against protein targets generated by **comparative modelling** also becomes possible for proteins whose structures are yet to be solved.
#
# Thus, the **_druggability_** of different compounds and their binding affinity on a given protein target can be calculated for further lead optimization processes.

# %% [markdown]
# <figure>
# <center>
# <img src='https://raw.githubusercontent.com/pb3lab/ibm3202/master/images/docking_01.png'/>
# <figcaption>FIGURE 1. In molecular docking, binding is evaluated in two steps: A) Energetics of the transition of the unbound states of ligand and target towards the conformations of the bound complex; and B) energetics of protein-ligand binding in these conformations. <br> Huey R et al (2007) <i>J Comput Chem 28(6), 1145-1152.</i></figcaption></center>
# </figure>

# %% [markdown]
# Molecular docking programs perform a **search algorithm** in which varying conformations of a given ligand, typically generated using Monte Carlo or Genetic algorithms, are recursively evaluated until convergence to an energy minimum is reached. Finally, through an **affinity scoring function**, a ΔG [binding free energy in kcal/mol] is estimated and employed to rank the candidate poses as the sum of several energetic contributions (electrostatics, van der Waals, desolvation, etc).

# %% [markdown]
# #Part I – Downloading inputs

# %%
#Here we download the input files from Github
# !wget https://speicherwolke.uni-leipzig.de/index.php/s/Mw2EjEYHmqkp4zo/download/ligand_docking.zip
#This remove command is just in case you had some previous input files
# !rm -rf input_files
#Here, we unzip the downloaded files
# !unzip ligand_docking.zip
# Out:
# --2022-05-12 15:33:33--  https://speicherwolke.uni-leipzig.de/index.php/s/Mw2EjEYHmqkp4zo/download/ligand_docking.zip
# Resolving speicherwolke.uni-leipzig.de (speicherwolke.uni-leipzig.de)... 139.18.16.135
# Connecting to speicherwolke.uni-leipzig.de (speicherwolke.uni-leipzig.de)|139.18.16.135|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 100362889 (96M) [application/zip]
# Saving to: ‘ligand_docking.zip’
#
# ligand_docking.zip  100%[===================>]  95.71M  1.77MB/s    in 89s
#
# 2022-05-12 15:35:03 (1.07 MB/s) - ‘ligand_docking.zip’ saved [100362889/100362889]
#
# Archive:  ligand_docking.zip
#    creating: ligand_docking/
#   inflating: ligand_docking/pymol_demo.png
#   inflating: ligand_docking/ligand_docking_presentation.pptx
#   inflating: ligand_docking/ligand_docking_presentation.pdf
#   inflating: ligand_docking/ligand_docking_tutorial.pdf
#    creating: ligand_docking/1_vanilla_docking/
#    creating: ligand_docking/1_vanilla_docking/ligand_prep/
#  extracting: ligand_docking/1_vanilla_docking/ligand_prep/.file
#   inflating: ligand_docking/1_vanilla_docking/ligand_prep/eticlopride_conformers.sdf
#   inflating: ligand_docking/1_vanilla_docking/ligand_prep/eticlopride.sdf
#    creating: ligand_docking/1_vanilla_docking/docking/
#   inflating: ligand_docking/1_vanilla_docking/docking/dock.xml
#   inflating: ligand_docking/1_vanilla_docking/docking/crystal_complex.pdb
#   inflating: ligand_docking/1_vanilla_docking/docking/options.txt
#    creating: ligand_docking/1_vanilla_docking/protein_prep/
#  extracting: ligand_docking/1_vanilla_docking/protein_prep/.file
#    creating: ligand_docking/1_vanilla_docking/answers/
#    creating: ligand_docking/1_vanilla_docking/answers/ligand_prep/
#   inflating: ligand_docking/1_vanilla_docking/answers/ligand_prep/eticlopride.sdf
#   inflating: ligand_docking/1_vanilla_docking/answers/ligand_prep/ETQ_conformers.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/ligand_prep/eticlopride_conformers.sdf
#   inflating: ligand_docking/1_vanilla_docking/answers/ligand_prep/ETQ.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/ligand_prep/ETQ.params
#    creating: ligand_docking/1_vanilla_docking/answers/docking/
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/listof_outputs
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/options.txt
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/calculate_rmsd_to_best_model.options
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/ETQ_conformers.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/ETQ.params
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/crystal_complex.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/3PBL_A_ETQ.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/ETQ.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/3PBL_A.pdb
#    creating: ligand_docking/1_vanilla_docking/answers/docking/out/
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0148.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0199.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0307.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0471.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/score_vs_low_rmsd_plot.png
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0010.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0134.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0223.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0133.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0224.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0289.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0258.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0300.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0476.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0017.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0372.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0404.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0065.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0287.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0141.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0190.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0256.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0478.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0019.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0280.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0146.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0197.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0251.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0309.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0375.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0403.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0062.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0264.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0173.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0218.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0057.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0391.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0436.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0340.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0086.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0108.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0050.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0431.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0396.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0347.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0081.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0263.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0174.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0211.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0106.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0398.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0349.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0022.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0443.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0335.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0492.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0025.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0444.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0495.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0332.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0216.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0101.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0059.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0438.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0088.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0323.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0484.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0034.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0455.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0099.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0048.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0429.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0110.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0207.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0358.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0389.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0117.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0200.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0483.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0324.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0033.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0452.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0356.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0090.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0041.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0387.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0420.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0119.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0165.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0272.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/score_vs_rmsd.csv
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0162.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0275.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0351.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0097.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0046.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0427.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0380.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0209.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0318.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0186.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0240.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0291.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0157.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0412.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0073.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0364.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0415.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0074.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0363.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0469.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0008.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0181.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0247.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0296.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0150.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0235.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0122.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0467.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0006.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0311.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0249.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0298.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0460.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/score.sc
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0001.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0316.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0188.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0159.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0232.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0125.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0024.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0445.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0333.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0494.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0217.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0100.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0058.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0439.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0089.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0210.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0107.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0399.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0348.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0023.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0442.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0493.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0334.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0109.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0051.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0397.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0430.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0346.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0080.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0262.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0175.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0265.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0172.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0219.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0056.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0437.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0390.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0341.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0087.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0281.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0147.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0196.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0250.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0308.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0374.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0402.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0063.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0373.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0405.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0064.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0286.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0140.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0191.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0257.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0479.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0018.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0132.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0225.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0288.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0259.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0301.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0477.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0016.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0149.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0198.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0306.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0470.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0011.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0135.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0222.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0461.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0317.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0189.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0158.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0233.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0124.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0234.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0123.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0466.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0007.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0310.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0248.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0299.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0414.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0075.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0362.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/score_vs_crystal_rmsd_plot.png
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0468.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0009.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0180.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0246.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0297.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0151.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0319.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0187.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0241.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0290.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0156.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0413.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0072.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0365.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0163.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0274.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0350.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0096.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0047.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0381.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0426.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0208.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0357.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0091.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0040.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0421.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0386.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0118.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0164.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0273.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0359.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0388.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0116.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0201.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0325.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0482.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0032.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0453.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0485.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0322.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0035.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0454.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0098.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0049.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0428.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0111.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0206.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0078.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0419.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0237.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0120.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0004.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0465.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0313.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0003.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0462.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0314.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0368.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0230.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0127.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0242.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0184.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0155.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0293.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0071.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0410.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0366.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0129.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0076.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0417.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0361.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0239.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0245.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0183.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0152.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0294.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0092.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0354.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0422.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0385.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0043.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0328.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0167.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0270.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0488.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0459.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0038.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0160.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0277.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0095.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0353.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0382.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0425.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0044.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0486.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0321.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0457.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0036.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0279.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0112.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0205.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0115.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0202.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0326.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0481.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0450.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0031.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0169.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0213.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0104.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0178.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0441.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0020.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0490.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0337.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0268.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0446.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0027.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0330.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0497.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0214.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0103.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0266.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0171.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0448.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0029.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0499.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0434.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0393.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0055.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0084.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0342.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0394.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0433.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0052.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0083.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0345.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0261.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0176.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0339.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0228.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0370.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0067.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0406.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0143.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0285.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0254.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0192.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0144.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0282.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0253.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0195.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0138.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0377.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0060.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0401.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0305.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0012.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0473.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0136.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0221.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0379.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0131.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0226.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0069.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0408.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0302.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0015.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0474.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0114.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0203.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0480.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0327.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0451.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0030.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0168.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0320.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0487.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0456.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0037.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0278.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0113.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0204.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0489.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0458.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0039.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0500.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0161.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0276.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0094.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0352.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0424.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0383.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0045.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0093.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0355.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0384.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0423.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0042.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0329.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0166.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0271.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0077.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0416.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0360.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0238.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0244.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0182.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0153.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0295.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0243.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0185.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0154.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0292.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0070.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0411.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0367.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0128.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0002.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0463.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0315.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0369.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0231.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0126.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0079.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0418.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0236.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0121.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0005.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0464.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0312.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0130.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0227.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0068.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0409.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/score_vs_low_rmsd_zoom_plot.png
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0303.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0014.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0475.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0304.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0013.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0472.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0137.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0220.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0378.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0145.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0283.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0252.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0194.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0139.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0376.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0061.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0400.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0229.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0371.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0066.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0407.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0142.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0284.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0255.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0193.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0432.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0395.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0053.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0082.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0344.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0260.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0177.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0338.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0267.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0170.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0449.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0028.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/rmsd_to_best_model.sc
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0498.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0392.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0435.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0054.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0085.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0343.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0269.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0447.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0026.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0496.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0331.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0215.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0102.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0212.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0105.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0179.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0440.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0021.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0336.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/out/3PBL_A_ETQ_0491.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/docking/calculate_rmsd_to_best_model.xml
#    creating: ligand_docking/1_vanilla_docking/answers/protein_prep/
#   inflating: ligand_docking/1_vanilla_docking/answers/protein_prep/3PBL_A.pdb
#   inflating: ligand_docking/1_vanilla_docking/answers/protein_prep/3PBL_A.fasta
#   inflating: ligand_docking/1_vanilla_docking/answers/protein_prep/3PBL.pdb
#    creating: ligand_docking/1_vanilla_docking/scripts/
#   inflating: ligand_docking/1_vanilla_docking/scripts/extract_scores.bash
#   inflating: ligand_docking/1_vanilla_docking/scripts/calculate_ligand_rmsd.py
#   inflating: ligand_docking/1_vanilla_docking/scripts/visualize_ligand.py
#   inflating: ligand_docking/ligand_docking_tutorial.md
#   inflating: ligand_docking/ligand_docking_tutorial.html

# %% [markdown]
# #Part II – Setting/Starting PyRosetta

# %% [markdown]
# ### Skip the following cell if you already installed PyRosetta

# %%
# Notebook setup
import sys
if 'google.colab' in sys.modules:
  # !pip install pyrosettacolabsetup
  import pyrosettacolabsetup
  pyrosettacolabsetup.install_pyrosetta()
  exit()

# %% [markdown]
# ### If you already have PyRosetta install run the following cell

# %%
# Notebook setup
import sys
if 'google.colab' in sys.modules:
    # !pip install pyrosettacolabsetup
    import pyrosettacolabsetup
    pyrosettacolabsetup.mount_pyrosetta_install()
    print ("Notebook is set for PyRosetta use in Colab.  Have fun!")

from pyrosetta import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/1n/w8bcjp390cn21tflbq7z261h0000gn/T/ipykernel_11354/3875451547.py in <module>
#       9 #from pyrosetta import *
#      10 #from rosetta.protocols.rosetta_scripts import *
# ---> 11 from pyrosetta import (
#      12     init, pose_from_sequence, pose_from_file, Pose, MoveMap, create_score_function, get_fa_scorefxn,
#      13     MonteCarlo, TrialMover, SwitchResidueTypeSetMover, PyJobDistributor,
#
# ModuleNotFoundError: No module named 'pyrosetta'

# %%
from pyrosetta import *

# %% [markdown]
# # Part III – Preparing and running the docking  protocols

# %% [markdown]
# 1. We start by setting up PyRosetta in Google Colab, based on your previously compiled and installed PyRosetta readily available in your Google Drive
#
# **⚠️WARNING:** Remember that you MUST have compiled and installed PyRosetta before this tutorial!

# %% [markdown]
# #### Docking ETQ

# %% [markdown]
# 1. In the following cell code we give PyRosetta all the needed **Flags**. These flags are equivalent to command-line instructions in order to set the path for files and set the value of different (and numerous) options. We pass them into PyRosetta, thus initializing it
#
#
# ```
# pyrosetta.distributed.init(flags)
# ```

# %% [markdown]
# The flags are explained briefly below
# ```
#
# #Pound signs indicate comments
#
# #-in:file:s option imports the protein and ligand PDB structures
# #-in:file:extra_res_fa option imports the parameters for the ligand
#
# -in
# 	-file
# 		-s '3PBL_A_ETQ.pdb'
# 		-extra_res_fa ETQ.params
#
# #the packing options allow Rosetta to sample additional rotamers for
# #protein sidechain angles chi 1 (ex1) and chi 2 (ex2)
# #no_optH false tells Rosetta to optimize hydrogen placements
# #flip_HNQ tells Rosetta to consider HIS,ASN,GLN hydrogen flips
# #ignore_ligand_chi prevents Roseta from adding additional ligand rotamer
#
# -packing
# 	-ex1
# 	-ex2
# 	-no_optH false
# 	-flip_HNQ true
# 	-ignore_ligand_chi true
#
#
# #parser:protocol locates the XML file for RosettaScripts
#
# -parser
# 	-protocol dock.xml
#
# #overwrite allows Rosetta to write over previous structures and scores
#
# -overwrite
#
# #Ligand docking is not yet benchmarked with the updated scoring function
# #This flag restores certain parameters to previously published values
#
# -mistakes
# 	-restore_pre_talaris_2013_behavior true
#
# ```

# %%
#Flags are equivalent to command-line instructions in order to set the path for files and set the value of different options 
ligand_params = "/content/ligand_docking/1_vanilla_docking/answers/ligand_prep/ETQ.params"
flags = f"""
-extra_res_fa {ligand_params}
-packing:ex1
-packing:ex2
-packing:no_optH false
-packing:flip_HNQ true
-ignore_unrecognized_res 1
-packing:ignore_ligand_chi true
-out:path:all /content/out
-overwrite
-corrections::restore_talaris_behavior
"""
pyrosetta.distributed.init(flags)

# %% [markdown]
# 2. One of the crucial concepts in PyRosetta are **poses**. They contain the information, sequence or structure, to which the protocol will be applied.

# %%
pose = pyrosetta.io.pose_from_file(filename="/content/ligand_docking/1_vanilla_docking/answers/docking/3PBL_A_ETQ.pdb")
scorefxn = pyrosetta.create_score_function("ligand.wts")

# %% [markdown]
# 3. While there are multiple ways of creating a protocol in Rosetta, in our case we are going to create a protocol from a **XML object**.

# %%
#Creating a Rosetta protocol from a XML object
#Note that in the <MOVERS> we specify the fragment files and the threaded_pdb!!

# %%time
xml = pyrosetta.rosetta.protocols.rosetta_scripts.XmlObjects.create_from_string("""
<ROSETTASCRIPTS>
		<SCOREFXNS>
			<ScoreFunction name="ligand_soft_rep" weights="ligand_soft_rep">
			</ScoreFunction>
			<ScoreFunction name="hard_rep" weights="ligand">
			</ScoreFunction>
		</SCOREFXNS>
    <RESIDUE_SELECTORS>
      <Chain name="chX" chains="X"/>
    </RESIDUE_SELECTORS>
    <SIMPLE_METRICS>
      <RMSDMetric name="rmsd_chX" residue_selector="chX" reference_name="store_native" residue_selector_ref="chX" robust="true" rmsd_type="rmsd_all" />
    </SIMPLE_METRICS>
		<LIGAND_AREAS>
			<LigandArea name="inhibitor_dock_sc" chain="X" cutoff="6.0" add_nbr_radius="true" all_atom_mode="false"/>
			<LigandArea name="inhibitor_final_sc" chain="X" cutoff="6.0" add_nbr_radius="true" all_atom_mode="false"/>
			<LigandArea name="inhibitor_final_bb" chain="X" cutoff="7.0" add_nbr_radius="false" all_atom_mode="true" Calpha_restraints="0.3"/>
		</LIGAND_AREAS>
		<INTERFACE_BUILDERS>
			<InterfaceBuilder name="side_chain_for_docking" ligand_areas="inhibitor_dock_sc"/>
			<InterfaceBuilder name="side_chain_for_final" ligand_areas="inhibitor_final_sc"/>
			<InterfaceBuilder name="backbone" ligand_areas="inhibitor_final_bb" extension_window="3"/>
		</INTERFACE_BUILDERS>
		<MOVEMAP_BUILDERS>
			<MoveMapBuilder name="docking" sc_interface="side_chain_for_docking" minimize_water="false"/>
			<MoveMapBuilder name="final" sc_interface="side_chain_for_final" bb_interface="backbone" minimize_water="false"/>
		</MOVEMAP_BUILDERS>
		<SCORINGGRIDS ligand_chain="X" width="15">
			<ClassicGrid grid_name="classic" weight="1.0"/>
		</SCORINGGRIDS>
		<MOVERS>
      <SavePoseMover name="spm" restore_pose="0" reference_name="store_native"/>
			<Transform name="transform" chain="X" box_size="7.0" move_distance="0.2" angle="20" cycles="500" repeats="1" temperature="5"/>
			<HighResDocker name="high_res_docker" cycles="6" repack_every_Nth="3" scorefxn="ligand_soft_rep" movemap_builder="docking"/>
			<FinalMinimizer name="final" scorefxn="hard_rep" movemap_builder="final"/>
			<InterfaceScoreCalculator name="add_scores" chains="X" scorefxn="hard_rep" native="/content/ligand_docking/1_vanilla_docking/docking/crystal_complex.pdb"/> 
		</MOVERS>
    <FILTERS>      
      <SimpleMetricFilter name="rmsd_chX" metric="rmsd_chX" cutoff="999999." comparison_type="lt" confidence="0"/>
    </FILTERS>
		<PROTOCOLS>
      <Add mover="spm"/>
			<Add mover_name="transform"/>
			<Add mover_name="high_res_docker"/>
			<Add mover_name="final"/>
			<Add mover_name="add_scores"/>
      <Add filter="rmsd_chX"/>
		</PROTOCOLS>
</ROSETTASCRIPTS>
    """).get_mover("ParsedProtocol")

# %% [markdown]
# 4. Once our protocol is set up, in the following code cells:
#   * We create the outputs directory
#   * We call the PyJobDistrubutor and pass three arguments
#     * A name prefix to output our models as PDB files
#     * The number of models to generate
#     * The score function to employ(ligands)
#   * We pass our pose to the job distributor that we just created
#   * Then, we create a Pandas dataframe to store the score results
#   * Finally, we loop while the jobs are not completed

# %%
import pandas as pd

if not os.getenv("DEBUG"):
    working_dir = os.getcwd()
    output_dir = "outputs"
    if not os.path.exists(output_dir):
        os.mkdir(output_dir)
    os.chdir(output_dir)

    jd = pyrosetta.toolbox.py_jobdistributor.PyJobDistributor(pdb_name="3PBL_ETQ",
                                                              nstruct=5,
                                                              scorefxn=scorefxn)
    jd.native_pose = pose
    df = pd.DataFrame()
    while not jd.job_complete:
        test_pose = pose.clone()
        xml.apply(test_pose)
        test_df = pd.DataFrame.from_records(dict(test_pose.scores), index=[jd.current_name])
        df = df.append(test_df)
        jd.output_decoy(test_pose)
    os.chdir(working_dir)

# %% [markdown]
# #Part IV – Analyze and visualize the modelled structures

# %% [markdown]
# 1. Now, we need to determine our best models by analyzing their score dataframes. For this, we are going to obtain the data frame for each of the models that we generated with PyRosetta.
#
#   We can visually inspect these data frames just writing their name in a code cell.

# %%
df

# %%
#Call here the name of the different dataframes that were created
# iterating the columns
for col in df.columns:
    print(col)

# %% [markdown]
# 2. As Rosetta uses an stochastic algorithm for comparative modelling, we are only interested in the low energy structures. Thus, we can sort our models by the column total_score as in the following cell code:

# %%
#hdf.sort_values('total_score')
df.sort_values('rmsd_chX')

# %% [markdown]
# 3. Having too many tables or tables with too much information would be challenging to analyze our results. For simplicity, we can make a plot with the **total_score** of each PDB for each species using **matplotlib**

# %%
import matplotlib
import seaborn
frames = [df]
results = pd.concat(frames)
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]
seaborn.barplot(x="rmsd_chX", y="index", data=results.sort_values('rmsd_chX').reset_index())

# %% [markdown]
# 4. Finally, we can take a look at our best models using **py3Dmol**

# %%
# !pip install py3Dmol
import py3Dmol
view=py3Dmol.view()
#Load the lowest RMSD structure
view.addModel(open('/content/outputs/3PBL_ETQ_YOURBESTMODEL.pdb', 'r').read(),'pdb')
view.zoomTo({'chain':'X'})
view.setBackgroundColor('white')
view.setStyle({'chain':'A'},{'cartoon': {'color':'purple'}})
#See residues that are a distance X from the residue 158
view.addStyle({'within':{'distance': 5,
                         'sel':{'chain':'X'}
                         }
               }
              ,{'stick':{'colorscheme':'greenCarbon'}
                }
              )
view.setStyle({'chain':'X'},{'stick':{'colorscheme':'blueCarbon'}})
#Using this line of code you can specify "The text","Opacity of the label","A selection of residues" 
view.addLabel("ETQ",{'fontOpacity':1},{'chain':'X'})
view.show()

# %% [markdown]
# **This is the end of the tutorial. Good Science!**

# %% [markdown]
# #Feedback and contact

# %% [markdown]
# Once you finish running this tutorial please give us feedback on https://www.menti.com/aeuyvnqmx2
#
# Felipe Engelberger, 2022
#
# **@fengel97** on twitter
